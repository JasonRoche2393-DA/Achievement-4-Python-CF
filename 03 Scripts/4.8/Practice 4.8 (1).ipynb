# %% [markdown]
# Importing libraries:

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Create data path:

# %%
# Create data path
path = r"C:\Users\Jason\Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\Jason\\Instacart Basket Analysis'

# %%
# Importing ords_prods_merge from previous exercise
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_prods_merge_derived.pkl'))

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(10)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             0   2539329        1             1                   2
# 2             0   2539329        1             1                   2
# 3             0   2539329        1             1                   2
# 4             0   2539329        1             1                   2
# 5             1   2398795        1             2                   3
# 6             1   2398795        1             2                   3
# 7             1   2398795        1             2                   3
# 8             1   2398795        1             2                   3
# 9             1   2398795        1             2                   3
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     7.0         196                  1
# 1                  8                     7.0       14084                  2
# 2                  8                     7.0       12427                  3
# 3                  8                     7.0       26088                  4
# 4                  8                     7.0       26405                  5
# 5                  7                    15.0         196                  1
# 6                  7                    15.0       10258                  2
# 7                  7                    15.0       12427                  3
# 8                  7                    15.0       13176                  4
# 9                  7                    15.0       26088                  5
#
#    reordered _merge  Unnamed: 0_y                             product_name  \
# 0          0   both           195                                     Soda
# 1          0   both         14084  Organic Unsweetened Vanilla Almond Milk
# 2          0   both         12427                      Original Beef Jerky
# 3          0   both         26089               Aged White Cheddar Popcorn
# 4          0   both         26406         XL Pick-A-Size Paper Towel Rolls
# 5          1   both           195                                     Soda
# 6          0   both         10258                               Pistachios
# 7          1   both         12427                      Original Beef Jerky
# 8          0   both         13176                   Bag of Organic Bananas
# 9          1   both         26089               Aged White Cheddar Popcorn
#
#    aisle_id  department_id  prices match    busiest_days busiest_period_of_day
# 0        77              7     9.0  both  Regularly busy        Average orders
# 1        91             16    12.5  both  Regularly busy        Average orders
# 2        23             19     4.4  both  Regularly busy        Average orders
# 3        23             19     4.7  both  Regularly busy        Average orders
# 4        54             17     1.0  both  Regularly busy        Average orders
# 5        77              7     9.0  both    Slowest days        Average orders
# 6       117             19     3.0  both    Slowest days        Average orders
# 7        23             19     4.4  both    Slowest days        Average orders
# 8        24              4    10.3  both    Slowest days        Average orders
# 9        23             19     4.7  both    Slowest days        Average orders

# %%
# Drop specified columns and overwrite the original DataFrame
df_ords_prods_merge = df_ords_prods_merge.drop(columns=['Unnamed: 0_x', 'Unnamed: 0_y', '_merge'])

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   match    busiest_days busiest_period_of_day
# 0  both  Regularly busy        Average orders
# 1  both  Regularly busy        Average orders
# 2  both  Regularly busy        Average orders
# 3  both  Regularly busy        Average orders
# 4  both  Regularly busy        Average orders

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_prods_merge_derived.pkl'))
