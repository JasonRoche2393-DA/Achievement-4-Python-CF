# %% [markdown]
# Importing libraries:

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# Create data path.

# %%
# Create data path
path = r"C:\Users\Jason\Instacart Basket Analysis"

# %%
# Importing df
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_prods_merge_derived.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   match    busiest_days busiest_period_of_day
# 0  both  Regularly busy        Average orders
# 1  both  Regularly busy        Average orders
# 2  both  Regularly busy        Average orders
# 3  both  Regularly busy        Average orders
# 4  both  Regularly busy        Average orders

# %%
# Creating a subset called df
df = df_ords_prods_merge

# %%
df = df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
df.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
# 5                    15.0         196                  1          1
# 6                    15.0       10258                  2          0
# 7                    15.0       12427                  3          1
# 8                    15.0       13176                  4          0
# 9                    15.0       26088                  5          1
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                     Soda        77              7     9.0
# 6                               Pistachios       117             19     3.0
# 7                      Original Beef Jerky        23             19     4.4
# 8                   Bag of Organic Bananas        24              4    10.3
# 9               Aged White Cheddar Popcorn        23             19     4.7
#
#   match    busiest_days busiest_period_of_day
# 0  both  Regularly busy        Average orders
# 1  both  Regularly busy        Average orders
# 2  both  Regularly busy        Average orders
# 3  both  Regularly busy        Average orders
# 4  both  Regularly busy        Average orders
# 5  both    Slowest days        Average orders
# 6  both    Slowest days        Average orders
# 7  both    Slowest days        Average orders
# 8  both    Slowest days        Average orders
# 9  both    Slowest days        Average orders

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Jason\AppData\Local\Temp\ipykernel_11124\136815596.py:1: FutureWarning: The provided callable <function max at 0x00000245C1142C00> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                     7.0       14084                  2          0
# 2                     7.0       12427                  3          0
# 3                     7.0       26088                  4          0
# 4                     7.0       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# 0                                     Soda        77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                      Original Beef Jerky        23             19     4.4
# 3               Aged White Cheddar Popcorn        23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
#
#   match    busiest_days busiest_period_of_day  max_order
# 0  both  Regularly busy        Average orders         10
# 1  both  Regularly busy        Average orders         10
# 2  both  Regularly busy        Average orders         10
# 3  both  Regularly busy        Average orders         10
# 4  both  Regularly busy        Average orders         10

# %%
df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# ..       ...      ...           ...                 ...                ...
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      7.0         196                  1          0
# 1                      7.0       14084                  2          0
# 2                      7.0       12427                  3          0
# 3                      7.0       26088                  4          0
# 4                      7.0       26405                  5          0
# ..                     ...         ...                ...        ...
# 95                     8.0       21150                 13          0
# 96                     8.0       47144                  1          0
# 97                     8.0        5322                  2          0
# 98                     8.0       17224                  3          0
# 99                     8.0       38656                  4          0
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# ..                                                ...       ...
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices match    busiest_days busiest_period_of_day  \
# 0               7     9.0  both  Regularly busy        Average orders
# 1              16    12.5  both  Regularly busy        Average orders
# 2              19     4.4  both  Regularly busy        Average orders
# 3              19     4.7  both  Regularly busy        Average orders
# 4              17     1.0  both  Regularly busy        Average orders
# ..            ...     ...   ...             ...                   ...
# 95              1     5.9  both  Regularly busy           Most orders
# 96             16    14.0  both    Slowest days           Most orders
# 97             19     2.9  both    Slowest days           Most orders
# 98             19     1.6  both    Slowest days           Most orders
# 99             19     3.4  both    Slowest days           Most orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# ..        ...
# 95         14
# 96         14
# 97         14
# 98         14
# 99         14
#
# [100 rows x 17 columns]

# %%
pd.options.display.max_rows = None

# %%
df_ords_prods_merge.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2539329        1             1                   2                  8
# 2    2539329        1             1                   2                  8
# 3    2539329        1             1                   2                  8
# 4    2539329        1             1                   2                  8
# 5    2398795        1             2                   3                  7
# 6    2398795        1             2                   3                  7
# 7    2398795        1             2                   3                  7
# 8    2398795        1             2                   3                  7
# 9    2398795        1             2                   3                  7
# 10   2398795        1             2                   3                  7
# 11    473747        1             3                   3                 12
# 12    473747        1             3                   3                 12
# 13    473747        1             3                   3                 12
# 14    473747        1             3                   3                 12
# 15    473747        1             3                   3                 12
# 16   2254736        1             4                   4                  7
# 17   2254736        1             4                   4                  7
# 18   2254736        1             4                   4                  7
# 19   2254736        1             4                   4                  7
# 20   2254736        1             4                   4                  7
# 21    431534        1             5                   4                 15
# 22    431534        1             5                   4                 15
# 23    431534        1             5                   4                 15
# 24    431534        1             5                   4                 15
# 25    431534        1             5                   4                 15
# 26    431534        1             5                   4                 15
# 27    431534        1             5                   4                 15
# 28    431534        1             5                   4                 15
# 29   3367565        1             6                   2                  7
# 30   3367565        1             6                   2                  7
# 31   3367565        1             6                   2                  7
# 32   3367565        1             6                   2                  7
# 33    550135        1             7                   1                  9
# 34    550135        1             7                   1                  9
# 35    550135        1             7                   1                  9
# 36    550135        1             7                   1                  9
# 37    550135        1             7                   1                  9
# 38   3108588        1             8                   1                 14
# 39   3108588        1             8                   1                 14
# 40   3108588        1             8                   1                 14
# 41   3108588        1             8                   1                 14
# 42   3108588        1             8                   1                 14
# 43   3108588        1             8                   1                 14
# 44   2295261        1             9                   1                 16
# 45   2295261        1             9                   1                 16
# 46   2295261        1             9                   1                 16
# 47   2295261        1             9                   1                 16
# 48   2295261        1             9                   1                 16
# 49   2295261        1             9                   1                 16
# 50   2550362        1            10                   4                  8
# 51   2550362        1            10                   4                  8
# 52   2550362        1            10                   4                  8
# 53   2550362        1            10                   4                  8
# 54   2550362        1            10                   4                  8
# 55   2550362        1            10                   4                  8
# 56   2550362        1            10                   4                  8
# 57   2550362        1            10                   4                  8
# 58   2550362        1            10                   4                  8
# 59   2168274        2             1                   2                 11
# 60   2168274        2             1                   2                 11
# 61   2168274        2             1                   2                 11
# 62   2168274        2             1                   2                 11
# 63   2168274        2             1                   2                 11
# 64   2168274        2             1                   2                 11
# 65   2168274        2             1                   2                 11
# 66   2168274        2             1                   2                 11
# 67   2168274        2             1                   2                 11
# 68   2168274        2             1                   2                 11
# 69   2168274        2             1                   2                 11
# 70   2168274        2             1                   2                 11
# 71   2168274        2             1                   2                 11
# 72   1501582        2             2                   5                 10
# 73   1501582        2             2                   5                 10
# 74   1501582        2             2                   5                 10
# 75   1501582        2             2                   5                 10
# 76   1501582        2             2                   5                 10
# 77   1501582        2             2                   5                 10
# 78   1901567        2             3                   1                 10
# 79   1901567        2             3                   1                 10
# 80   1901567        2             3                   1                 10
# 81   1901567        2             3                   1                 10
# 82   1901567        2             3                   1                 10
# 83    738281        2             4                   2                 10
# 84    738281        2             4                   2                 10
# 85    738281        2             4                   2                 10
# 86    738281        2             4                   2                 10
# 87    738281        2             4                   2                 10
# 88    738281        2             4                   2                 10
# 89    738281        2             4                   2                 10
# 90    738281        2             4                   2                 10
# 91    738281        2             4                   2                 10
# 92    738281        2             4                   2                 10
# 93    738281        2             4                   2                 10
# 94    738281        2             4                   2                 10
# 95    738281        2             4                   2                 10
# 96   1673511        2             5                   3                 11
# 97   1673511        2             5                   3                 11
# 98   1673511        2             5                   3                 11
# 99   1673511        2             5                   3                 11
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      7.0         196                  1          0
# 1                      7.0       14084                  2          0
# 2                      7.0       12427                  3          0
# 3                      7.0       26088                  4          0
# 4                      7.0       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
# 15                    21.0       30450                  5          0
# 16                    29.0         196                  1          1
# 17                    29.0       12427                  2          1
# 18                    29.0       10258                  3          1
# 19                    29.0       25133                  4          1
# 20                    29.0       26405                  5          1
# 21                    28.0         196                  1          1
# 22                    28.0       12427                  2          1
# 23                    28.0       10258                  3          1
# 24                    28.0       25133                  4          1
# 25                    28.0       10326                  5          0
# 26                    28.0       17122                  6          0
# 27                    28.0       41787                  7          0
# 28                    28.0       13176                  8          1
# 29                    19.0         196                  1          1
# 30                    19.0       12427                  2          1
# 31                    19.0       10258                  3          1
# 32                    19.0       25133                  4          1
# 33                    20.0         196                  1          1
# 34                    20.0       10258                  2          1
# 35                    20.0       12427                  3          1
# 36                    20.0       25133                  4          1
# 37                    20.0       13032                  5          1
# 38                    14.0       12427                  1          1
# 39                    14.0         196                  2          1
# 40                    14.0       10258                  3          1
# 41                    14.0       25133                  4          1
# 42                    14.0       46149                  5          0
# 43                    14.0       49235                  6          0
# 44                     0.0       49235                  1          1
# 45                     0.0       46149                  2          1
# 46                     0.0       25133                  3          1
# 47                     0.0         196                  4          1
# 48                     0.0       10258                  5          1
# 49                     0.0       12427                  6          1
# 50                    30.0         196                  1          1
# 51                    30.0       46149                  2          1
# 52                    30.0       39657                  3          0
# 53                    30.0       38928                  4          0
# 54                    30.0       25133                  5          1
# 55                    30.0       10258                  6          1
# 56                    30.0       35951                  7          0
# 57                    30.0       13032                  8          1
# 58                    30.0       12427                  9          1
# 59                     7.0       32792                  1          0
# 60                     7.0       47766                  2          0
# 61                     7.0       20574                  3          0
# 62                     7.0       12000                  4          0
# 63                     7.0       48110                  5          0
# 64                     7.0       22474                  6          0
# 65                     7.0       16589                  7          0
# 66                     7.0       35917                  8          0
# 67                     7.0       27344                  9          0
# 68                     7.0       30489                 10          0
# 69                     7.0       27966                 11          0
# 70                     7.0       13176                 12          0
# 71                     7.0       45066                 13          0
# 72                    10.0       16797                  1          0
# 73                    10.0       47526                  2          0
# 74                    10.0        8479                  3          0
# 75                    10.0       47766                  4          1
# 76                    10.0       19051                  5          0
# 77                    10.0        8138                  6          0
# 78                     3.0       47766                  1          1
# 79                     3.0       32792                  2          1
# 80                     3.0       20574                  3          1
# 81                     3.0        7781                  4          0
# 82                     3.0       28874                  5          0
# 83                     8.0       49451                  1          0
# 84                     8.0       32792                  2          1
# 85                     8.0       32139                  3          0
# 86                     8.0       34688                  4          0
# 87                     8.0       36735                  5          0
# 88                     8.0       37646                  6          0
# 89                     8.0       22829                  7          0
# 90                     8.0       24852                  8          0
# 91                     8.0       47209                  9          0
# 92                     8.0       33276                 10          0
# 93                     8.0       45613                 11          0
# 94                     8.0        9681                 12          0
# 95                     8.0       21150                 13          0
# 96                     8.0       47144                  1          0
# 97                     8.0        5322                  2          0
# 98                     8.0       17224                  3          0
# 99                     8.0       38656                  4          0
#
#                                          product_name  aisle_id  \
# 0                                                Soda        77
# 1             Organic Unsweetened Vanilla Almond Milk        91
# 2                                 Original Beef Jerky        23
# 3                          Aged White Cheddar Popcorn        23
# 4                    XL Pick-A-Size Paper Towel Rolls        54
# 5                                                Soda        77
# 6                                          Pistachios       117
# 7                                 Original Beef Jerky        23
# 8                              Bag of Organic Bananas        24
# 9                          Aged White Cheddar Popcorn        23
# 10                              Cinnamon Toast Crunch       121
# 11                                               Soda        77
# 12                                Original Beef Jerky        23
# 13                                         Pistachios       117
# 14                              Organic String Cheese        21
# 15                               Creamy Almond Butter        88
# 16                                               Soda        77
# 17                                Original Beef Jerky        23
# 18                                         Pistachios       117
# 19                              Organic String Cheese        21
# 20                   XL Pick-A-Size Paper Towel Rolls        54
# 21                                               Soda        77
# 22                                Original Beef Jerky        23
# 23                                         Pistachios       117
# 24                              Organic String Cheese        21
# 25                                Organic Fuji Apples        24
# 26                                  Honeycrisp Apples        24
# 27                                     Bartlett Pears        24
# 28                             Bag of Organic Bananas        24
# 29                                               Soda        77
# 30                                Original Beef Jerky        23
# 31                                         Pistachios       117
# 32                              Organic String Cheese        21
# 33                                               Soda        77
# 34                                         Pistachios       117
# 35                                Original Beef Jerky        23
# 36                              Organic String Cheese        21
# 37                              Cinnamon Toast Crunch       121
# 38                                Original Beef Jerky        23
# 39                                               Soda        77
# 40                                         Pistachios       117
# 41                              Organic String Cheese        21
# 42                                  Zero Calorie Cola        77
# 43                                Organic Half & Half        53
# 44                                Organic Half & Half        53
# 45                                  Zero Calorie Cola        77
# 46                              Organic String Cheese        21
# 47                                               Soda        77
# 48                                         Pistachios       117
# 49                                Original Beef Jerky        23
# 50                                               Soda        77
# 51                                  Zero Calorie Cola        77
# 52                             Milk Chocolate Almonds        45
# 53                           0% Greek Strained Yogurt       120
# 54                              Organic String Cheese        21
# 55                                         Pistachios       117
# 56                    Organic Unsweetened Almond Milk        91
# 57                              Cinnamon Toast Crunch       121
# 58                                Original Beef Jerky        23
# 59                     Chipotle Beef & Pork Realstick        23
# 60                                    Organic Avocado        24
# 61                                     Roasted Turkey        96
# 62           Baked Organic Sea Salt Crunchy Pea Snack        72
# 63            Thin Stackers Brown Rice Lightly Salted        78
# 64                     Cheddar Bunnies Snack Crackers        78
# 65                                     Plantain Chips       107
# 66                   Organic Just Concord Grape Juice        98
# 67                               Uncured Genoa Salami        96
# 68                                    Original Hummus        67
# 69                                Organic Raspberries       123
# 70                             Bag of Organic Bananas        24
# 71                                   Honeycrisp Apple        24
# 72                                       Strawberries        24
# 73                                    Goat Cheese Log        21
# 74              Original Black Box Tablewater Cracker        78
# 75                                    Organic Avocado        24
# 76               Pita Chips, Simply Naked, Party Size       107
# 77                                 Traditional Hummus        67
# 78                                    Organic Avocado        24
# 79                     Chipotle Beef & Pork Realstick        23
# 80                                     Roasted Turkey        96
# 81  Organic Sticks Low Moisture Part Skim Mozzarel...        21
# 82                                 Carrot Ginger Soup         1
# 83                              Artichoke Spinach Dip        67
# 84                     Chipotle Beef & Pork Realstick        23
# 85                            Hommus Classic Original        67
# 86  Good Belly Probiotics Juice Drink Blueberry Ac...        31
# 87              Organic Roasted Sliced Chicken Breast        96
# 88                                Organic Gala Apples        24
# 89          Multigrain Flax Seeded Flatbread Crackers        78
# 90                                             Banana        24
# 91                               Organic Hass Avocado        24
# 92                              Kalamata Olive Spread        67
# 93                                           Pad Thai        38
# 94  Chicken Tikka Masala with Cumin Infused Basmat...        38
# 95                            Fire Grilled Steak Bowl        38
# 96     Unsweetened Original Almond Breeze Almond Milk        91
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3
# 98                   Oats & Honey Gluten Free Granola         3
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3
#
#     department_id  prices match    busiest_days busiest_period_of_day  \
# 0               7     9.0  both  Regularly busy        Average orders
# 1              16    12.5  both  Regularly busy        Average orders
# 2              19     4.4  both  Regularly busy        Average orders
# 3              19     4.7  both  Regularly busy        Average orders
# 4              17     1.0  both  Regularly busy        Average orders
# 5               7     9.0  both    Slowest days        Average orders
# 6              19     3.0  both    Slowest days        Average orders
# 7              19     4.4  both    Slowest days        Average orders
# 8               4    10.3  both    Slowest days        Average orders
# 9              19     4.7  both    Slowest days        Average orders
# 10             14     4.0  both    Slowest days        Average orders
# 11              7     9.0  both    Slowest days           Most orders
# 12             19     4.4  both    Slowest days           Most orders
# 13             19     3.0  both    Slowest days           Most orders
# 14             16     8.6  both    Slowest days           Most orders
# 15             13     3.2  both    Slowest days           Most orders
# 16              7     9.0  both    Slowest days        Average orders
# 17             19     4.4  both    Slowest days        Average orders
# 18             19     3.0  both    Slowest days        Average orders
# 19             16     8.6  both    Slowest days        Average orders
# 20             17     1.0  both    Slowest days        Average orders
# 21              7     9.0  both    Slowest days           Most orders
# 22             19     4.4  both    Slowest days           Most orders
# 23             19     3.0  both    Slowest days           Most orders
# 24             16     8.6  both    Slowest days           Most orders
# 25              4     2.7  both    Slowest days           Most orders
# 26              4    14.0  both    Slowest days           Most orders
# 27              4     5.0  both    Slowest days           Most orders
# 28              4    10.3  both    Slowest days           Most orders
# 29              7     9.0  both  Regularly busy        Average orders
# 30             19     4.4  both  Regularly busy        Average orders
# 31             19     3.0  both  Regularly busy        Average orders
# 32             16     8.6  both  Regularly busy        Average orders
# 33              7     9.0  both    Busiest days           Most orders
# 34             19     3.0  both    Busiest days           Most orders
# 35             19     4.4  both    Busiest days           Most orders
# 36             16     8.6  both    Busiest days           Most orders
# 37             14     4.0  both    Busiest days           Most orders
# 38             19     4.4  both    Busiest days           Most orders
# 39              7     9.0  both    Busiest days           Most orders
# 40             19     3.0  both    Busiest days           Most orders
# 41             16     8.6  both    Busiest days           Most orders
# 42              7    13.4  both    Busiest days           Most orders
# 43             16     1.8  both    Busiest days           Most orders
# 44             16     1.8  both    Busiest days           Most orders
# 45              7    13.4  both    Busiest days           Most orders
# 46             16     8.6  both    Busiest days           Most orders
# 47              7     9.0  both    Busiest days           Most orders
# 48             19     3.0  both    Busiest days           Most orders
# 49             19     4.4  both    Busiest days           Most orders
# 50              7     9.0  both    Slowest days        Average orders
# 51              7    13.4  both    Slowest days        Average orders
# 52             19     6.8  both    Slowest days        Average orders
# 53             16    12.6  both    Slowest days        Average orders
# 54             16     8.6  both    Slowest days        Average orders
# 55             19     3.0  both    Slowest days        Average orders
# 56             16     1.3  both    Slowest days        Average orders
# 57             14     4.0  both    Slowest days        Average orders
# 58             19     4.4  both    Slowest days        Average orders
# 59             19     5.2  both  Regularly busy           Most orders
# 60              4     6.3  both  Regularly busy           Most orders
# 61             20     2.3  both  Regularly busy           Most orders
# 62             13    10.9  both  Regularly busy           Most orders
# 63             19     2.7  both  Regularly busy           Most orders
# 64             19     4.1  both  Regularly busy           Most orders
# 65             19     5.0  both  Regularly busy           Most orders
# 66              7     9.4  both  Regularly busy           Most orders
# 67             20    14.8  both  Regularly busy           Most orders
# 68             20     7.5  both  Regularly busy           Most orders
# 69              4     4.4  both  Regularly busy           Most orders
# 70              4    10.3  both  Regularly busy           Most orders
# 71              4     2.5  both  Regularly busy           Most orders
# 72              4     1.3  both  Regularly busy           Most orders
# 73             16     2.0  both  Regularly busy           Most orders
# 74             19     3.5  both  Regularly busy           Most orders
# 75              4     6.3  both  Regularly busy           Most orders
# 76             19     3.9  both  Regularly busy           Most orders
# 77             20     2.0  both  Regularly busy           Most orders
# 78              4     6.3  both    Busiest days           Most orders
# 79             19     5.2  both    Busiest days           Most orders
# 80             20     2.3  both    Busiest days           Most orders
# 81             16     6.6  both    Busiest days           Most orders
# 82             20     6.2  both    Busiest days           Most orders
# 83             20     7.1  both  Regularly busy           Most orders
# 84             19     5.2  both  Regularly busy           Most orders
# 85             20     7.5  both  Regularly busy           Most orders
# 86              7     5.8  both  Regularly busy           Most orders
# 87             20     8.9  both  Regularly busy           Most orders
# 88              4     9.1  both  Regularly busy           Most orders
# 89             19     5.5  both  Regularly busy           Most orders
# 90              4    12.3  both  Regularly busy           Most orders
# 91              4     4.0  both  Regularly busy           Most orders
# 92             20    10.8  both  Regularly busy           Most orders
# 93              1    12.6  both  Regularly busy           Most orders
# 94              1     2.0  both  Regularly busy           Most orders
# 95              1     5.9  both  Regularly busy           Most orders
# 96             16    14.0  both    Slowest days           Most orders
# 97             19     2.9  both    Slowest days           Most orders
# 98             19     1.6  both    Slowest days           Most orders
# 99             19     3.4  both    Slowest days           Most orders
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         10
# 11         10
# 12         10
# 13         10
# 14         10
# 15         10
# 16         10
# 17         10
# 18         10
# 19         10
# 20         10
# 21         10
# 22         10
# 23         10
# 24         10
# 25         10
# 26         10
# 27         10
# 28         10
# 29         10
# 30         10
# 31         10
# 32         10
# 33         10
# 34         10
# 35         10
# 36         10
# 37         10
# 38         10
# 39         10
# 40         10
# 41         10
# 42         10
# 43         10
# 44         10
# 45         10
# 46         10
# 47         10
# 48         10
# 49         10
# 50         10
# 51         10
# 52         10
# 53         10
# 54         10
# 55         10
# 56         10
# 57         10
# 58         10
# 59         14
# 60         14
# 61         14
# 62         14
# 63         14
# 64         14
# 65         14
# 66         14
# 67         14
# 68         14
# 69         14
# 70         14
# 71         14
# 72         14
# 73         14
# 74         14
# 75         14
# 76         14
# 77         14
# 78         14
# 79         14
# 80         14
# 81         14
# 82         14
# 83         14
# 84         14
# 85         14
# 86         14
# 87         14
# 88         14
# 89         14
# 90         14
# 91         14
# 92         14
# 93         14
# 94         14
# 95         14
# 96         14
# 97         14
# 98         14
# 99         14

# %%
# Setting up loyalty tag
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Setting up loyalty tag
# ----> 2 df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1880, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1878     self.obj[key] = empty_value
#    1879 elif not is_list_like(value):
# -> 1880     self.obj[key] = construct_1d_array_from_inferred_fill_value(
#    1881         value, len(self.obj)
#    1882     )
#    1883 else:
#    1884     # FIXME: GH#42099#issuecomment-864326014
#    1885     self.obj[key] = infer_fill_value(value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5267, in DataFrame._sanitize_column(self, value)
#    5265 if is_list_like(value):
#    5266     com.require_length_match(value, self.index)
# -> 5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#    5275     warnings.warn(
#    5276         "Setting an Index with object dtype into a DataFrame will stop "
#    5277         "inferring another dtype in a future version. Cast the Index "
#    (...)
#    5280         stacklevel=find_stack_level(),
#    5281     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1189, in maybe_infer_to_datetimelike(value)
#    1184     return value
#    1186 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1187 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1188 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1189 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1190     value,
#    1191     # Here we do not convert numeric dtypes, as if we wanted that,
#    1192     #  numpy would have done it for us.
#    1193     convert_numeric=False,
#    1194     convert_non_numeric=True,
#    1195     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1196 )
#
# File lib.pyx:2539, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 494. MiB for an array with shape (32404859,) and data type complex128

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1880, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1878     self.obj[key] = empty_value
#    1879 elif not is_list_like(value):
# -> 1880     self.obj[key] = construct_1d_array_from_inferred_fill_value(
#    1881         value, len(self.obj)
#    1882     )
#    1883 else:
#    1884     # FIXME: GH#42099#issuecomment-864326014
#    1885     self.obj[key] = infer_fill_value(value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5267, in DataFrame._sanitize_column(self, value)
#    5265 if is_list_like(value):
#    5266     com.require_length_match(value, self.index)
# -> 5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#    5275     warnings.warn(
#    5276         "Setting an Index with object dtype into a DataFrame will stop "
#    5277         "inferring another dtype in a future version. Cast the Index "
#    (...)
#    5280         stacklevel=find_stack_level(),
#    5281     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1189, in maybe_infer_to_datetimelike(value)
#    1184     return value
#    1186 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1187 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1188 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1189 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1190     value,
#    1191     # Here we do not convert numeric dtypes, as if we wanted that,
#    1192     #  numpy would have done it for us.
#    1193     convert_numeric=False,
#    1194     convert_non_numeric=True,
#    1195     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1196 )
#
# File lib.pyx:2539, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 494. MiB for an array with shape (32404859,) and data type complex128

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1880, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1878     self.obj[key] = empty_value
#    1879 elif not is_list_like(value):
# -> 1880     self.obj[key] = construct_1d_array_from_inferred_fill_value(
#    1881         value, len(self.obj)
#    1882     )
#    1883 else:
#    1884     # FIXME: GH#42099#issuecomment-864326014
#    1885     self.obj[key] = infer_fill_value(value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5267, in DataFrame._sanitize_column(self, value)
#    5265 if is_list_like(value):
#    5266     com.require_length_match(value, self.index)
# -> 5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#    5275     warnings.warn(
#    5276         "Setting an Index with object dtype into a DataFrame will stop "
#    5277         "inferring another dtype in a future version. Cast the Index "
#    (...)
#    5280         stacklevel=find_stack_level(),
#    5281     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\construction.py:606, in sanitize_array(data, index, dtype, copy, allow_2d)
#     604 subarr = data
#     605 if data.dtype == object:
# --> 606     subarr = maybe_infer_to_datetimelike(data)
#     607     if (
#     608         object_index
#     609         and using_pyarrow_string_dtype()
#     610         and is_string_dtype(subarr)
#     611     ):
#     612         # Avoid inference when string option is set
#     613         subarr = data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1189, in maybe_infer_to_datetimelike(value)
#    1184     return value
#    1186 # error: Incompatible return value type (got "Union[ExtensionArray,
#    1187 # ndarray[Any, Any]]", expected "Union[ndarray[Any, Any], DatetimeArray,
#    1188 # TimedeltaArray, PeriodArray, IntervalArray]")
# -> 1189 return lib.maybe_convert_objects(  # type: ignore[return-value]
#    1190     value,
#    1191     # Here we do not convert numeric dtypes, as if we wanted that,
#    1192     #  numpy would have done it for us.
#    1193     convert_numeric=False,
#    1194     convert_non_numeric=True,
#    1195     dtype_if_all_nat=np.dtype("M8[ns]"),
#    1196 )
#
# File lib.pyx:2539, in pandas._libs.lib.maybe_convert_objects()
#
# MemoryError: Unable to allocate 494. MiB for an array with shape (32404859,) and data type complex128

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loyalty_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'loyalty_flag'

# %%
print(df_ords_prods_merge.columns)
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'match', 'busiest_days',
#        'busiest_period_of_day', 'max_order'],
#       dtype='object')

# %%
df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['loyalty_flag'] not in index"
